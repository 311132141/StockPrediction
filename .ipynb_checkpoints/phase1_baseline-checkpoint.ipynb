# %%
pip install xgboost
# Out:
# Collecting xgboost
#   Using cached xgboost-2.1.4-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from xgboost) (1.15.1)
# Downloading xgboost-2.1.4-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    - -------------------------------------- 5.2/124.9 MB 28.1 MB/s eta 0:00:05
#    --- ------------------------------------ 11.3/124.9 MB 28.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 16.5/124.9 MB 27.3 MB/s eta 0:00:04
#    ------- -------------------------------- 22.3/124.9 MB 27.2 MB/s eta 0:00:04
#    -------- ------------------------------- 26.7/124.9 MB 25.9 MB/s eta 0:00:04
#    ---------- ----------------------------- 33.6/124.9 MB 26.9 MB/s eta 0:00:04
#    ------------- -------------------------- 40.9/124.9 MB 28.0 MB/s eta 0:00:04
#    ------------- -------------------------- 42.5/124.9 MB 26.8 MB/s eta 0:00:04
#    --------------- ------------------------ 49.3/124.9 MB 26.2 MB/s eta 0:00:03
#    ------------------ --------------------- 56.6/124.9 MB 27.0 MB/s eta 0:00:03
#    -------------------- ------------------- 63.4/124.9 MB 27.7 MB/s eta 0:00:03
#    ---------------------- ----------------- 70.8/124.9 MB 28.2 MB/s eta 0:00:02
#    ------------------------- -------------- 78.1/124.9 MB 28.7 MB/s eta 0:00:02
#    --------------------------- ------------ 85.5/124.9 MB 29.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 92.5/124.9 MB 29.3 MB/s eta 0:00:02
#    ------------------------------- -------- 99.6/124.9 MB 29.6 MB/s eta 0:00:01
#    --------------------------------- ----- 106.7/124.9 MB 29.9 MB/s eta 0:00:01
#    ----------------------------------- --- 114.0/124.9 MB 30.1 MB/s eta 0:00:01
#    ------------------------------------- - 120.3/124.9 MB 30.1 MB/s eta 0:00:01
#    --------------------------------------  124.8/124.9 MB 30.2 MB/s eta 0:00:01
#    --------------------------------------- 124.9/124.9 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: xgboost
# Successfully installed xgboost-2.1.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Using cached lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from lightgbm) (1.15.1)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 14.2 MB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh
# Out:
#   Cell In[51], line 1
#     curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh
#                  ^
# SyntaxError: invalid syntax

# %%
pip install catboost
# Out:
# Collecting catboost
#   Using cached catboost-1.2.7.tar.gz (71.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   pip subprocess to install build dependencies did not run successfully.
#   exit code: 1
#
#   [135 lines of output]
#   Collecting setuptools>=64.0
#     Using cached setuptools-75.8.2-py3-none-any.whl.metadata (6.7 kB)
#   Collecting wheel
#     Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
#   Collecting jupyterlab==3.*,>=3.0.6
#     Using cached jupyterlab-3.6.8-py3-none-any.whl.metadata (12 kB)
#   Collecting conan~=1.62
#     Using cached conan-1.66.0.tar.gz (789 kB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting ipython (from jupyterlab==3.*,>=3.0.6)
#     Using cached ipython-9.0.0-py3-none-any.whl.metadata (4.3 kB)
#   Collecting packaging (from jupyterlab==3.*,>=3.0.6)
#     Using cached packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
#   Collecting tornado>=6.1.0 (from jupyterlab==3.*,>=3.0.6)
#     Using cached tornado-6.4.2-cp38-abi3-win_amd64.whl.metadata (2.6 kB)
#   Collecting jupyter-core (from jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_core-5.7.2-py3-none-any.whl.metadata (3.4 kB)
#   Collecting jupyterlab-server~=2.19 (from jupyterlab==3.*,>=3.0.6)
#     Using cached jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
#   Collecting jupyter-server<3,>=1.16.0 (from jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
#   Collecting jupyter-ydoc~=0.2.4 (from jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_ydoc-0.2.5-py3-none-any.whl.metadata (2.2 kB)
#   Collecting jupyter-server-ydoc~=0.8.0 (from jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_server_ydoc-0.8.0-py3-none-any.whl.metadata (5.3 kB)
#   Collecting nbclassic (from jupyterlab==3.*,>=3.0.6)
#     Using cached nbclassic-1.2.0-py3-none-any.whl.metadata (3.6 kB)
#   Collecting notebook<7 (from jupyterlab==3.*,>=3.0.6)
#     Using cached notebook-6.5.7-py3-none-any.whl.metadata (2.5 kB)
#   Collecting jinja2>=2.1 (from jupyterlab==3.*,>=3.0.6)
#     Using cached jinja2-3.1.5-py3-none-any.whl.metadata (2.6 kB)
#   Collecting requests<3.0.0,>=2.25 (from conan~=1.62)
#     Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
#   Collecting urllib3<1.27,>=1.26.6 (from conan~=1.62)
#     Using cached urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#   Collecting colorama<0.5.0,>=0.3.3 (from conan~=1.62)
#     Using cached colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
#   Collecting PyYAML<6.1,>=3.11 (from conan~=1.62)
#     Using cached PyYAML-6.0.2-cp313-cp313-win_amd64.whl.metadata (2.1 kB)
#   Collecting patch-ng<1.18,>=1.17.4 (from conan~=1.62)
#     Using cached patch-ng-1.17.4.tar.gz (17 kB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting fasteners>=0.14.1 (from conan~=1.62)
#     Using cached fasteners-0.19-py3-none-any.whl.metadata (4.9 kB)
#   Collecting six<=1.16.0,>=1.10.0 (from conan~=1.62)
#     Using cached six-1.16.0-py2.py3-none-any.whl.metadata (1.8 kB)
#   Collecting node-semver==0.6.1 (from conan~=1.62)
#     Using cached node_semver-0.6.1-py3-none-any.whl.metadata (2.1 kB)
#   Collecting pygments<3.0,>=2.0 (from conan~=1.62)
#     Using cached pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
#   Collecting tqdm<5,>=4.28.1 (from conan~=1.62)
#     Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
#   Collecting python-dateutil<3,>=2.7.0 (from conan~=1.62)
#     Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
#   Collecting bottle<0.13,>=0.12.8 (from conan~=1.62)
#     Using cached bottle-0.12.25-py3-none-any.whl.metadata (1.8 kB)
#   Collecting pluginbase>=0.5 (from conan~=1.62)
#     Using cached pluginbase-1.0.1.tar.gz (43 kB)
#     Preparing metadata (setup.py): started
#     Preparing metadata (setup.py): finished with status 'done'
#   Collecting PyJWT<3.0.0,>=2.4.0 (from conan~=1.62)
#     Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
#   Collecting MarkupSafe>=2.0 (from jinja2>=2.1->jupyterlab==3.*,>=3.0.6)
#     Using cached MarkupSafe-3.0.2-cp313-cp313-win_amd64.whl.metadata (4.1 kB)
#   Collecting anyio>=3.1.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached anyio-4.8.0-py3-none-any.whl.metadata (4.6 kB)
#   Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
#   Collecting jupyter-client>=7.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
#   Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
#   Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
#   Collecting nbconvert>=6.4.4 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
#   Collecting nbformat>=5.3.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
#   Collecting overrides>=5.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
#   Collecting prometheus-client>=0.9 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
#   Collecting pywinpty>=2.0.1 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached pywinpty-2.0.15-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
#   Collecting pyzmq>=24 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached pyzmq-26.2.1-cp313-cp313-win_amd64.whl.metadata (6.2 kB)
#   Collecting send2trash>=1.8.2 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
#   Collecting terminado>=0.8.3 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
#   Collecting traitlets>=5.6.0 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
#   Collecting websocket-client>=1.7 (from jupyter-server<3,>=1.16.0->jupyterlab==3.*,>=3.0.6)
#     Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
#   Collecting platformdirs>=2.5 (from jupyter-core->jupyterlab==3.*,>=3.0.6)
#     Using cached platformdirs-4.3.6-py3-none-any.whl.metadata (11 kB)
#   Collecting pywin32>=300 (from jupyter-core->jupyterlab==3.*,>=3.0.6)
#     Using cached pywin32-308-cp313-cp313-win_amd64.whl.metadata (8.3 kB)
#   Collecting jupyter-server-fileid<1,>=0.6.0 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.6)
#     Using cached jupyter_server_fileid-0.9.3-py3-none-any.whl.metadata (4.7 kB)
#   Collecting ypy-websocket<0.9.0,>=0.8.2 (from jupyter-server-ydoc~=0.8.0->jupyterlab==3.*,>=3.0.6)
#     Using cached ypy_websocket-0.8.4-py3-none-any.whl.metadata (2.5 kB)
#   Collecting y-py<0.7.0,>=0.6.0 (from jupyter-ydoc~=0.2.4->jupyterlab==3.*,>=3.0.6)
#     Using cached y_py-0.6.2.tar.gz (53 kB)
#     Installing build dependencies: started
#     Installing build dependencies: finished with status 'done'
#     Getting requirements to build wheel: started
#     Getting requirements to build wheel: finished with status 'done'
#     Preparing metadata (pyproject.toml): started
#     Preparing metadata (pyproject.toml): finished with status 'error'
#     error: subprocess-exited-with-error
#
#     Preparing metadata (pyproject.toml) did not run successfully.
#     exit code: 1
#
#     [6 lines of output]
#
#     Cargo, the Rust package manager, is not installed or is not on PATH.
#     This package requires Rust and Cargo to compile extensions. Install it through
#     the system's package manager or via https://rustup.rs/
#
#     Checking for Rust toolchain....
#     [end of output]
#
#     note: This error originates from a subprocess, and is likely not a problem with pip.
#   error: metadata-generation-failed
#
#   Encountered error while generating package metadata.
#
#   See above for output.
#
#   note: This is an issue with the package mentioned above, not pip.
#   hint: See above for details.
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# pip subprocess to install build dependencies did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-0.2.54-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: requests>=2.31 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from yfinance) (2.32.3)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\johni\appdata\roaming\python\python313\site-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from yfinance) (2024.1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.6-py313-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-3.17.9.tar.gz (3.0 MB)
#      ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#      ------------------------------- -------- 2.4/3.0 MB 12.6 MB/s eta 0:00:01
#      ---------------------------------------- 3.0/3.0 MB 11.8 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from requests>=2.31->yfinance) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)
# Downloading yfinance-0.2.54-py2.py3-none-any.whl (108 kB)
# Downloading frozendict-2.4.6-py313-none-any.whl (16 kB)
# Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Building wheels for collected packages: peewee
#   Building wheel for peewee (pyproject.toml): started
#   Building wheel for peewee (pyproject.toml): finished with status 'done'
#   Created wheel for peewee: filename=peewee-3.17.9-py3-none-any.whl size=139096 sha256=26b30cce44ee005c45f47d816a02e071ba9b1a4c77ee7ca1b4dc52f3418def2e
#   Stored in directory: c:\users\johni\appdata\local\pip\cache\wheels\a4\4c\13\c0145c208d813977081d42e2a47d72acb3efc4a6965ab57804
# Successfully built peewee
# Installing collected packages: peewee, multitasking, frozendict, yfinance
# Successfully installed frozendict-2.4.6 multitasking-0.0.11 peewee-3.17.9 yfinance-0.2.54
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip uninstall pandas_ta numpy -y
# !pip install numpy pandas_ta
# Out:
# Found existing installation: pandas_ta 0.3.14b0
# Uninstalling pandas_ta-0.3.14b0:
#   Successfully uninstalled pandas_ta-0.3.14b0
# Found existing installation: numpy 2.2.2
# Uninstalling numpy-2.2.2:
#   Successfully uninstalled numpy-2.2.2
# Collecting numpy
#   Downloading numpy-2.2.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas_ta) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Downloading numpy-2.2.3-cp313-cp313-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 3.1/12.6 MB 15.8 MB/s eta 0:00:01
#    --------------------- ------------------ 6.8/12.6 MB 16.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.8/12.6 MB 18.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 18.4 MB/s eta 0:00:00
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py): started
#   Building wheel for pandas_ta (setup.py): finished with status 'done'
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=219006 sha256=e7c1b351361fd26a8d7de4c32fc82cf0463390cb9945720cd7ab8a2de5b5490a
#   Stored in directory: c:\users\johni\appdata\local\pip\cache\wheels\b6\52\9c\0cf5f2d9a8659797eecc4bf8254d38c41d4838effb19cf1877
# Successfully built pandas_ta
# Installing collected packages: numpy, pandas_ta
# Successfully installed numpy-2.2.3 pandas_ta-0.3.14b0

# %%
# !pip uninstall numpy -y
# !pip install numpy==1.26.4
# Out:
# Collecting numpy==1.26.4
#   Downloading numpy-1.26.4.tar.gz (15.8 MB)
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ----------- ---------------------------- 4.7/15.8 MB 27.8 MB/s eta 0:00:01
#      --------------------------- ----------- 11.0/15.8 MB 29.0 MB/s eta 0:00:01
#      --------------------------------------- 15.8/15.8 MB 26.2 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Building wheels for collected packages: numpy
#   Building wheel for numpy (pyproject.toml): started
#   Building wheel for numpy (pyproject.toml): finished with status 'done'
#   Created wheel for numpy: filename=numpy-1.26.4-cp313-cp313-win_amd64.whl size=6081966 sha256=a1e619621caa1d6c396bb09d448595eab763e1b2f874279dd8ce06d798e6c3c4
#   Stored in directory: c:\users\johni\appdata\local\pip\cache\wheels\8b\2d\9f\b6b46373f328e2ef50388915d351ccacbedac929459b5459bf
# Successfully built numpy
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.3
#     Uninstalling numpy-2.2.3:
#       Successfully uninstalled numpy-2.2.3
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.26.4

# %%
pip install --upgrade pandas_ta
# Out:
# Requirement already satisfied: pandas_ta in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (0.3.14b0)
# Requirement already satisfied: pandas in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas_ta) (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas->pandas_ta) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade pip setuptools wheel
# Out:
# Requirement already satisfied: pip in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (25.0)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (72.1.0)
# Collecting setuptools
#   Using cached setuptools-75.8.2-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: wheel in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (0.45.1)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 17.5 MB/s eta 0:00:00
# Using cached setuptools-75.8.2-py3-none-any.whl (1.2 MB)
# Installing collected packages: setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 72.1.0
#     Uninstalling setuptools-72.1.0:
#       Successfully uninstalled setuptools-72.1.0
#   Attempting uninstall: pip
#     Found existing installation: pip 25.0
#     Uninstalling pip-25.0:
#       Successfully uninstalled pip-25.0
# Successfully installed pip-25.0.1 setuptools-75.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\johni\anaconda3\envs\stock_env\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import ta
from scipy.stats import zscore

# Sklearn imports for scaling, splitting, modeling, evaluation, and hyperparameter tuning
from sklearn.model_selection import TimeSeriesSplit, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import (
    RandomForestClassifier,
    GradientBoostingClassifier,
    AdaBoostClassifier,
    ExtraTreesClassifier
)
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Additional libraries for boosting models
import xgboost as xgb
import lightgbm as lgb
# from catboost import CatBoostClassifier

# %%
# Example: Download data using yfinance library (install it if needed: pip install yfinance)
import yfinance as yf

# Define the ticker symbol (e.g., "AAPL" for Apple Inc.)
ticker = "AAPL"

# Download historical data (last 5 years)
data = yf.download(ticker, period="5y", interval="1d")

# Save the data to a CSV file for later use
data.to_csv("data/stock_data.csv")

# Display the first few rows
data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2020-03-02  72.514900  73.153147  67.396802  68.503417  341397200
# 2020-03-03  70.211891  73.774417  69.357656  73.694336  319475600
# 2020-03-04  73.468636  73.628805  71.136494  71.939761  219178400
# 2020-03-05  71.085548  72.694504  70.719101  71.716508  187572800
# 2020-03-06  70.141533  70.575931  68.248639  68.435499  226176800

# %%
df = pd.read_csv(
    "data/stock_data.csv",
    skiprows=3,                # Skip the first two lines
    names=["Date", "Close", "High", "Low", "Open", "Volume"]
)
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)
print(df.head())
print("\nData Description:")
print(df.describe())
# Out:
#                 Close       High        Low       Open     Volume
# Date
# 2020-03-02  72.514900  73.153147  67.396802  68.503417  341397200
# 2020-03-03  70.211891  73.774417  69.357656  73.694336  319475600
# 2020-03-04  73.468636  73.628805  71.136494  71.939761  219178400
# 2020-03-05  71.085548  72.694504  70.719101  71.716508  187572800
# 2020-03-06  70.141533  70.575931  68.248639  68.435499  226176800
#
# Data Description:
#              Close         High          Low         Open        Volume
# count  1257.000000  1257.000000  1257.000000  1257.000000  1.257000e+03
# mean    157.228474   158.813945   155.458454   157.070720  8.755033e+07
# std      42.191351    42.344391    41.944233    42.126041  5.140841e+07
# min      54.449894    55.452160    51.595990    55.350235  2.323470e+07
# 25%     130.434799   131.739666   128.802410   130.512547  5.409170e+07
# 50%     154.516647   156.655657   152.036458   154.521719  7.415070e+07
# 75%     181.559296   182.801568   179.810963   181.084946  1.026888e+08
# max     258.735504   259.814335   257.347047   257.906429  4.184740e+08

# %%
# Plot the Close price over time
plt.figure(figsize=(12, 6))
plt.plot(df.index, df['Close'])
plt.title("Close Price Over Time")
plt.xlabel("Date")
plt.ylabel("Close Price")
plt.show()

# %%
# Plot correlation heatmap for numerical features
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# ---------------------------
# Outlier Detection & Handling
# ---------------------------
# Remove outliers from the 'Close' column using a z-score threshold (|z| < 3)
df['Close_z'] = zscore(df['Close'])
df = df[df['Close_z'].abs() < 3]
df.drop(columns=['Close_z'], inplace=True)

# %%
# ---------------------------
# Feature Engineering
# ---------------------------
# Create Technical Indicators using ta (instead of pandas_ta)

# 1. Simple Moving Average (SMA) for a 20-day period
df['SMA20'] = ta.trend.SMAIndicator(df['Close'], window=20).sma_indicator()

# 2. Exponential Moving Average (EMA) for a 20-day period
df['EMA20'] = ta.trend.EMAIndicator(df['Close'], window=20).ema_indicator()

# 3. Relative Strength Index (RSI) with a 14-day period
df['RSI'] = ta.momentum.RSIIndicator(df['Close'], window=14).rsi()

# 4. Moving Average Convergence Divergence (MACD)
macd = ta.trend.MACD(df['Close'], window_slow=26, window_fast=12, window_sign=9)
df['MACD'] = macd.macd()
df['MACD_Signal'] = macd.macd_signal()
df['MACD_Hist'] = macd.macd_diff()

# Drop initial rows with NaNs after indicator calculations
df.dropna(inplace=True)

# Generate "Returns" Feature: daily percentage change in 'Close'
df['Return'] = df['Close'].pct_change()
df.dropna(inplace=True)

# Define the binary Target: 1 if next day's Close > today's, else 0
df['Target'] = (df['Close'].shift(-1) > df['Close']).astype(int)
df.dropna(inplace=True)

print(df.head())
# Out:
#                 Close       High        Low       Open     Volume      SMA20  \
# Date
# 2020-04-20  67.205093  68.357819  67.185682  67.452631  130015200  63.174325
# 2020-04-21  65.127785  67.282776  64.414308  67.047377  180991600  63.708219
# 2020-04-22  67.003677  67.440497  66.057231  66.399402  116862400  64.062773
# 2020-04-23  66.744011  68.374814  66.705181  66.947860  124814400  64.420846
# 2020-04-24  68.670891  68.680600  67.222097  67.270635  126161200  64.718492
#
#                 EMA20        RSI      MACD  MACD_Signal  MACD_Hist    Return  \
# Date
# 2020-04-20  65.204363  54.423804  0.993354     0.003637   0.989718 -0.020757
# 2020-04-21  65.197070  49.967485  0.840476     0.171005   0.669471 -0.030910
# 2020-04-22  65.369128  53.657739  0.860765     0.308957   0.551809  0.028803
# 2020-04-23  65.500069  53.074186  0.846138     0.416393   0.429745 -0.003875
# 2020-04-24  65.802052  56.826412  0.978747     0.528864   0.449883  0.028870
#
#             Target
# Date
# 2020-04-20       0
# 2020-04-21       1
# 2020-04-22       0
# 2020-04-23       1
# 2020-04-24       1

# %%
# ---------------------------
# Data Scaling
# ---------------------------
# Define feature columns; adjust as needed
features = ['Close', 'High', 'Low', 'Open', 'Volume', 'SMA20', 'EMA20', 'RSI', 
            'MACD', 'MACD_Signal', 'MACD_Hist', 'Return']
X = df[features]
y = df['Target']

# Standardize features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), index=X.index, columns=X.columns)

# %%
# ---------------------------
# Train/Test Split: Chronological
# ---------------------------
train_size = int(len(X_scaled) * 0.8)
X_train = X_scaled.iloc[:train_size]
X_test  = X_scaled.iloc[train_size:]
y_train = y.iloc[:train_size]
y_test  = y.iloc[train_size:]

print("Training set size:", X_train.shape, " Testing set size:", X_test.shape)
# Out:
# Training set size: (978, 12)  Testing set size: (245, 12)

# %%
# Create and train the logistic regression model
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)

# Make predictions
y_pred = lr_model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.39591836734693875
# Confusion Matrix:
#  [[ 82  18]
#  [130  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.82      0.53       100
#            1       0.45      0.10      0.17       145
#
#     accuracy                           0.40       245
#    macro avg       0.42      0.46      0.35       245
# weighted avg       0.43      0.40      0.31       245

# %%
# ---------------------------
# Models Dictionary for Classification
# ---------------------------
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Random Forest": RandomForestClassifier(n_estimators=100, max_depth=5, random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(),
    "SVC": SVC(probability=True),
    "KNN Classifier": KNeighborsClassifier(),
    "Decision Tree": DecisionTreeClassifier(),
    "MLP Classifier": MLPClassifier(max_iter=1000),
    "AdaBoost": AdaBoostClassifier(),
    "ExtraTrees": ExtraTreesClassifier(n_estimators=100, max_depth=5, random_state=42),
    "XGBoost": xgb.XGBClassifier(use_label_encoder=False, eval_metric='logloss'),
    "LightGBM": lgb.LGBMClassifier(),
}

# %%
# Set trading surcharge (e.g., 0.1% per trade)
surcharge = 0.001

# Create a dictionary to store cumulative returns for each model
cumulative_returns = {}

# Loop over each model
for name, model in models.items():
    print(f"Processing model: {name}")
    # Fit the model on the training set
    model.fit(X_train, y_train)
    # Predict on the test set
    y_pred = model.predict(X_test)
    
    # Create a Series of predictions with the same index as X_test
    signal = pd.Series(y_pred, index=X_test.index)
    
    # Get the actual daily returns from the original dataframe for the test period
    daily_returns = df.loc[X_test.index, "Return"]
    
    # Determine when a trade occurs (signal changes from the previous day)
    # For the first day, if signal==1, we assume a trade occurs to enter the position.
    trade_change = signal != signal.shift(1)
    trade_change.iloc[0] = True if signal.iloc[0] == 1 else False
    
    # Compute effective daily return: if signal==1, gain is daily_return; if signal==0, gain is 0.
    # Additionally, subtract the trading surcharge (cost) on days when a trade occurs.
    effective_daily_return = daily_returns * signal - trade_change.astype(float) * surcharge
    
    # Compute cumulative return over the test period
    cum_return = (1 + effective_daily_return).cumprod()
    
    # Store the cumulative return series in the dictionary
    cumulative_returns[name] = cum_return
# Out:
# Processing model: Logistic Regression
# Processing model: Random Forest
# Processing model: Gradient Boosting
# Processing model: SVC
# Processing model: KNN Classifier
# Processing model: Decision Tree
# Processing model: MLP Classifier
# Processing model: AdaBoost
# Processing model: ExtraTrees
# Processing model: XGBoost
# Processing model: LightGBM
# [LightGBM] [Info] Number of positive: 510, number of negative: 468
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000496 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3060
# [LightGBM] [Info] Number of data points in the train set: 978, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.521472 -> initscore=0.085942
# [LightGBM] [Info] Start training from score 0.085942
# C:\Users\johni\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:20:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# C:\Users\johni\anaconda3\envs\stock_env\Lib\site-packages\joblib\externals\loky\backend\context.py:136: UserWarning: Could not find the number of physical cores for the following reason:
# [WinError 2] The system cannot find the file specified
# Returning the number of logical cores instead. You can silence this warning by setting LOKY_MAX_CPU_COUNT to the number of cores you want to use.
#   warnings.warn(
#   File "C:\Users\johni\anaconda3\envs\stock_env\Lib\site-packages\joblib\externals\loky\backend\context.py", line 257, in _count_physical_cores
#     cpu_info = subprocess.run(
#         "wmic CPU Get NumberOfCores /Format:csv".split(),
#         capture_output=True,
#         text=True,
#     )
#   File "C:\Users\johni\anaconda3\envs\stock_env\Lib\subprocess.py", line 556, in run
#     with Popen(*popenargs, **kwargs) as process:
#          ~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\johni\anaconda3\envs\stock_env\Lib\subprocess.py", line 1038, in __init__
#     self._execute_child(args, executable, preexec_fn, close_fds,
#     ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#                         pass_fds, cwd, env,
#                         ^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#                         gid, gids, uid, umask,
#                         ^^^^^^^^^^^^^^^^^^^^^^
#                         start_new_session, process_group)
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\johni\anaconda3\envs\stock_env\Lib\subprocess.py", line 1550, in _execute_child
#     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#                        ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^
#                              # no special security
#                              ^^^^^^^^^^^^^^^^^^^^^
#     ...<4 lines>...
#                              cwd,
#                              ^^^^
#                              startupinfo)
#                              ^^^^^^^^^^^^

# %%
# ---------------------------
# Plot All Models' Cumulative Returns on a Single Graph
# ---------------------------
plt.figure(figsize=(14, 8))
colors = plt.cm.tab10.colors  # a palette with at least 10 colors
for idx, (name, cum_return) in enumerate(cumulative_returns.items()):
    plt.plot(cum_return.index, cum_return, label=name, color=colors[idx % len(colors)], linewidth=2)

plt.xlabel("Date")
plt.ylabel("Cumulative Return")
plt.title("Backtesting: Strategy Cumulative Returns with Trading Surcharge")
plt.legend()
plt.grid(True)
plt.show()

# %%
from matplotlib.lines import Line2D

# ---------------------------
# Fit, Predict, and Plot for Each Model
# ---------------------------
for name, model in models.items():
    print(f"---- {name} ----")
    # Fit the classifier on the training set
    model.fit(X_train, y_train)
    # Predict the test set
    y_pred = model.predict(X_test)
    # Calculate accuracy and print performance metrics
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print("Classification Report:\n", classification_report(y_test, y_pred))
    
    # Create a color list: red if prediction==1 (up), blue if prediction==0 (down)
    colors = ['red' if pred == 1 else 'blue' for pred in y_pred]
    
    # Plot the test data's Close price, coloring each point based on the prediction.
    plt.figure(figsize=(12, 6))
    plt.scatter(X_test.index, X_test['Close'], c=colors, alpha=0.7)
    plt.title(f"{name} Predictions on Test Data")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    
    # Create custom legend handles
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Price Up (1)', markerfacecolor='red', markersize=10),
        Line2D([0], [0], marker='o', color='w', label='Price Down (0)', markerfacecolor='blue', markersize=10)
    ]
    plt.legend(handles=legend_elements)
    
    plt.show()
# Out:
# ---- Logistic Regression ----
# Accuracy: 0.39591836734693875
# Confusion Matrix:
#  [[ 82  18]
#  [130  15]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.82      0.53       100
#            1       0.45      0.10      0.17       145
#
#     accuracy                           0.40       245
#    macro avg       0.42      0.46      0.35       245
# weighted avg       0.43      0.40      0.31       245
# ---- Random Forest ----
# Accuracy: 0.4448979591836735
# Confusion Matrix:
#  [[ 85  15]
#  [121  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.41      0.85      0.56       100
#            1       0.62      0.17      0.26       145
#
#     accuracy                           0.44       245
#    macro avg       0.51      0.51      0.41       245
# weighted avg       0.53      0.44      0.38       245
# ---- Gradient Boosting ----
# Accuracy: 0.5224489795918368
# Confusion Matrix:
#  [[52 48]
#  [69 76]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.52      0.47       100
#            1       0.61      0.52      0.57       145
#
#     accuracy                           0.52       245
#    macro avg       0.52      0.52      0.52       245
# weighted avg       0.54      0.52      0.53       245
# ---- SVC ----
# Accuracy: 0.4163265306122449
# Confusion Matrix:
#  [[ 81  19]
#  [124  21]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.81      0.53       100
#            1       0.53      0.14      0.23       145
#
#     accuracy                           0.42       245
#    macro avg       0.46      0.48      0.38       245
# weighted avg       0.47      0.42      0.35       245
# ---- KNN Classifier ----
# Accuracy: 0.42857142857142855
# Confusion Matrix:
#  [[ 70  30]
#  [110  35]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.70      0.50       100
#            1       0.54      0.24      0.33       145
#
#     accuracy                           0.43       245
#    macro avg       0.46      0.47      0.42       245
# weighted avg       0.48      0.43      0.40       245
# ---- Decision Tree ----
# Accuracy: 0.4530612244897959
# Confusion Matrix:
#  [[ 73  27]
#  [107  38]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.41      0.73      0.52       100
#            1       0.58      0.26      0.36       145
#
#     accuracy                           0.45       245
#    macro avg       0.50      0.50      0.44       245
# weighted avg       0.51      0.45      0.43       245
# ---- MLP Classifier ----
# Accuracy: 0.46122448979591835
# Confusion Matrix:
#  [[ 84  16]
#  [116  29]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.84      0.56       100
#            1       0.64      0.20      0.31       145
#
#     accuracy                           0.46       245
#    macro avg       0.53      0.52      0.43       245
# weighted avg       0.55      0.46      0.41       245
# ---- AdaBoost ----
# Accuracy: 0.44081632653061226
# Confusion Matrix:
#  [[ 81  19]
#  [118  27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.41      0.81      0.54       100
#            1       0.59      0.19      0.28       145
#
#     accuracy                           0.44       245
#    macro avg       0.50      0.50      0.41       245
# weighted avg       0.51      0.44      0.39       245
# ---- ExtraTrees ----
# Accuracy: 0.4122448979591837
# Confusion Matrix:
#  [[ 82  18]
#  [126  19]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.39      0.82      0.53       100
#            1       0.51      0.13      0.21       145
#
#     accuracy                           0.41       245
#    macro avg       0.45      0.48      0.37       245
# weighted avg       0.46      0.41      0.34       245
# ---- XGBoost ----
# Accuracy: 0.43673469387755104
# Confusion Matrix:
#  [[ 80  20]
#  [118  27]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.80      0.54       100
#            1       0.57      0.19      0.28       145
#
#     accuracy                           0.44       245
#    macro avg       0.49      0.49      0.41       245
# weighted avg       0.50      0.44      0.39       245
# C:\Users\johni\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py:158: UserWarning: [20:21:32] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# ---- LightGBM ----
# [LightGBM] [Info] Number of positive: 510, number of negative: 468
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000213 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3060
# [LightGBM] [Info] Number of data points in the train set: 978, number of used features: 12
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.521472 -> initscore=0.085942
# [LightGBM] [Info] Start training from score 0.085942
# Accuracy: 0.42857142857142855
# Confusion Matrix:
#  [[ 87  13]
#  [127  18]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.41      0.87      0.55       100
#            1       0.58      0.12      0.20       145
#
#     accuracy                           0.43       245
#    macro avg       0.49      0.50      0.38       245
# weighted avg       0.51      0.43      0.35       245

# %%
# ---------------------------
# Plot Predictions on Training Data for Each Model
# ---------------------------
for name, model in models.items():
    print(f"---- {name} on Training Data ----")
    # Fit the model on training data
    model.fit(X_train, y_train)
    # Predict on training data
    y_train_pred = model.predict(X_train)
    accuracy = accuracy_score(y_train, y_train_pred)
    print("Accuracy:", accuracy)
    print("Confusion Matrix:\n", confusion_matrix(y_train, y_train_pred))
    print("Classification Report:\n", classification_report(y_train, y_train_pred))
    # Create color mapping: red if predicted 1 (up), blue if predicted 0 (down)
    colors_train = ['red' if pred == 1 else 'blue' for pred in y_train_pred]
    
    # Create scatter plot for training data
    plt.figure(figsize=(12, 6))
    plt.scatter(X_train.index, X_train['Close'], c=colors_train, alpha=0.7)
    plt.title(f"{name} Predictions on Training Data")
    plt.xlabel("Date")
    plt.ylabel("Close Price")
    
    # Create a custom legend
    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='Price Up (1)', markerfacecolor='red', markersize=10),
        Line2D([0], [0], marker='o', color='w', label='Price Down (0)', markerfacecolor='blue', markersize=10)
    ]
    plt.legend(handles=legend_elements)
    plt.show()
# Out:
# ---- Logistic Regression on Training Data ----
# Accuracy: 0.5472689075630253
# Confusion Matrix:
#  [[193 265]
#  [166 328]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.54      0.42      0.47       458
#            1       0.55      0.66      0.60       494
#
#     accuracy                           0.55       952
#    macro avg       0.55      0.54      0.54       952
# weighted avg       0.55      0.55      0.54       952
# ---- Random Forest on Training Data ----
# Accuracy: 0.7552521008403361
# Confusion Matrix:
#  [[286 172]
#  [ 61 433]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.82      0.62      0.71       458
#            1       0.72      0.88      0.79       494
#
#     accuracy                           0.76       952
#    macro avg       0.77      0.75      0.75       952
# weighted avg       0.77      0.76      0.75       952
# ---- Gradient Boosting on Training Data ----
# Accuracy: 0.8508403361344538
# Confusion Matrix:
#  [[357 101]
#  [ 41 453]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.78      0.83       458
#            1       0.82      0.92      0.86       494
#
#     accuracy                           0.85       952
#    macro avg       0.86      0.85      0.85       952
# weighted avg       0.86      0.85      0.85       952
# ---- SVC on Training Data ----
# Accuracy: 0.5903361344537815
# Confusion Matrix:
#  [[171 287]
#  [103 391]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.37      0.47       458
#            1       0.58      0.79      0.67       494
#
#     accuracy                           0.59       952
#    macro avg       0.60      0.58      0.57       952
# weighted avg       0.60      0.59      0.57       952
# ---- KNN Classifier on Training Data ----
# Accuracy: 0.6607142857142857
# Confusion Matrix:
#  [[295 163]
#  [160 334]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.65      0.64      0.65       458
#            1       0.67      0.68      0.67       494
#
#     accuracy                           0.66       952
#    macro avg       0.66      0.66      0.66       952
# weighted avg       0.66      0.66      0.66       952
# ---- Decision Tree on Training Data ----
# Accuracy: 1.0
# Confusion Matrix:
#  [[458   0]
#  [  0 494]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       458
#            1       1.00      1.00      1.00       494
#
#     accuracy                           1.00       952
#    macro avg       1.00      1.00      1.00       952
# weighted avg       1.00      1.00      1.00       952
# ---- MLP Classifier on Training Data ----
# Accuracy: 0.707983193277311
# Confusion Matrix:
#  [[312 146]
#  [132 362]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.70      0.68      0.69       458
#            1       0.71      0.73      0.72       494
#
#     accuracy                           0.71       952
#    macro avg       0.71      0.71      0.71       952
# weighted avg       0.71      0.71      0.71       952
# ---- AdaBoost on Training Data ----
# Accuracy: 0.6092436974789915
# Confusion Matrix:
#  [[211 247]
#  [125 369]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.46      0.53       458
#            1       0.60      0.75      0.66       494
#
#     accuracy                           0.61       952
#    macro avg       0.61      0.60      0.60       952
# weighted avg       0.61      0.61      0.60       952
# ---- ExtraTrees on Training Data ----
# Accuracy: 0.6302521008403361
# Confusion Matrix:
#  [[205 253]
#  [ 99 395]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.45      0.54       458
#            1       0.61      0.80      0.69       494
#
#     accuracy                           0.63       952
#    macro avg       0.64      0.62      0.61       952
# weighted avg       0.64      0.63      0.62       952
# ---- XGBoost on Training Data ----
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_25696\871395129.py in ?()
#       3 # ---------------------------
#       4 for name, model in models.items():
#       5     print(f"---- {name} on Training Data ----")
#       6     # Fit the model on training data
# ----> 7     model.fit(X_train, y_train)
#       8     # Predict on training data
#       9     y_train_pred = model.predict(X_train)
#      10     accuracy = accuracy_score(y_train, y_train_pred)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\sklearn.py in ?(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1576                     params["objective"] = "multi:softprob"
#    1577                 params["num_class"] = self.n_classes_
#    1578
#    1579             model, metric, params = self._configure_fit(xgb_model, params)
# -> 1580             train_dmatrix, evals = _wrap_evaluation_matrices(
#    1581                 missing=self.missing,
#    1582                 X=X,
#    1583                 y=y,
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\sklearn.py in ?(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     599     feature_types: Optional[FeatureTypes],
#     600 ) -> Tuple[Any, List[Tuple[Any, str]]]:
#     601     """Convert array_like evaluation matrices into DMatrix.  Perform validation on the
#     602     way."""
# --> 603     train_dmatrix = create_dmatrix(
#     604         data=X,
#     605         label=y,
#     606         group=group,
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\sklearn.py in ?(self, ref, **kwargs)
#    1064             try:
#    1065                 return QuantileDMatrix(
#    1066                     **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1067                 )
# -> 1068             except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1069                 pass
#    1070         return DMatrix(**kwargs, nthread=self.n_jobs)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, data_split_mode)
#    1569                     "If data iterator is used as input, data like label should be "
#    1570                     "specified as batch argument."
#    1571                 )
#    1572
# -> 1573         self._init(
#    1574             data,
#    1575             ref=ref,
#    1576             label=label,
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(self, data, ref, enable_categorical, **meta)
#    1628             next_callback,
#    1629             config,
#    1630             ctypes.byref(handle),
#    1631         )
# -> 1632         it.reraise()
#    1633         # delay check_call to throw intermediate exception first
#    1634         _check_call(ret)
#    1635         self.handle = handle
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(self)
#     565             #  pylint 2.7.0 believes `self._exception` can be None even with `assert
#     566             #  isinstace`
#     567             exc = self._exception
#     568             self._exception = None
# --> 569             raise exc  # pylint: disable=raising-bad-type
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(self, fn, dft_ret)
#     555             tb = sys.exc_info()[2]
#     556             # On dask, the worker is restarted and somehow the information is
#     557             # lost.
#     558             self._exception = e.with_traceback(tb)
# --> 559         return dft_ret
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?()
# --> 637         return self._handle_exception(lambda: self.next(input_data), 0)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\data.py in ?(self, input_data)
#    1398     def next(self, input_data: Callable) -> int:
#    1399         if self.it == 1:
#    1400             return 0
#    1401         self.it += 1
# -> 1402         input_data(**self.kwargs)
#    1403         return 1
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(*args, **kwargs)
#     722                     raise TypeError(msg)
#     723                 warnings.warn(msg, FutureWarning)
#     724             for k, arg in zip(sig.parameters, args):
#     725                 kwargs[k] = arg
# --> 726             return func(**kwargs)
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\core.py in ?(data, feature_names, feature_types, **kwargs)
#     613                 and ref is self._data_ref
#     614             ):
#     615                 new, cat_codes, feature_names, feature_types = self._temporary_data
#     616             else:
# --> 617                 new, cat_codes, feature_names, feature_types = _proxy_transform(
#     618                     data,
#     619                     feature_names,
#     620                     feature_types,
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\data.py in ?(data, feature_names, feature_types, enable_categorical)
#    1443         data = pd.DataFrame(data)
#    1444     if _is_arrow(data):
#    1445         data = _arrow_transform(data)
#    1446     if _is_pandas_df(data):
# -> 1447         df, feature_names, feature_types = _transform_pandas_df(
#    1448             data, enable_categorical, feature_names, feature_types
#    1449         )
#    1450         return df, None, feature_names, feature_types
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\data.py in ?(data, enable_categorical, feature_names, feature_types, meta)
#     607     feature_names, feature_types = pandas_feature_info(
#     608         data, meta, feature_names, feature_types, enable_categorical
#     609     )
#     610
# --> 611     arrays = pandas_transform_data(data)
#     612     return PandasTransformed(arrays), feature_names, feature_types
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\data.py in ?(data)
#     546             if _is_np_array_like(arr):
#     547                 arr, _ = _ensure_np_dtype(arr, arr.dtype)
#     548             result.append(arr)
#     549         else:
# --> 550             result.append(oth_type(data[col]))
#     551
#     552     # FIXME(jiamingy): Investigate the possibility of using dataframe protocol or arrow
#     553     # IPC format for pandas so that we can apply the data transformation inside XGBoost
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\xgboost\data.py in ?(ser)
#     511     def oth_type(ser: pd.Series) -> np.ndarray:
#     512         # The dtypes module is added in 1.25.
#     513         npdtypes = np.lib.NumpyVersion(np.__version__) > np.lib.NumpyVersion("1.25.0")
#     514         npdtypes = npdtypes and isinstance(
# --> 515             ser.dtype,
#     516             (
#     517                 # pylint: disable=no-member
#     518                 np.dtypes.Float32DType,  # type: ignore
#
# ~\anaconda3\envs\stock_env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
